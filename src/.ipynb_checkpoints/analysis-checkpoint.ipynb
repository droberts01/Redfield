# %%
#---------------
# analysis.py 
# Provides functions for analysis of
# the Redfield quantum master equation and its solution.

import json
import meta
import meta_functions
import numpy as np
from time import time
from pathlib import Path
import matplotlib.pyplot as plt

# call as "simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])"
def simulate(args):
    start = time()
    
    # Parse input as float
    args = [float(num) for num in args]
    tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = args
    tQA = float('{:0.3e}'.format(tQA))
    args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence]
                
    decoherence = int(decoherence)
	# args for constructing F-model Hamiltonian
    H_args = [I, J, K, int(N)]

	# args pertaining to numerical implementation of the QME
    N_args = [int(Nc), [step, window_size, int(num_samples)]]
    svals, bad_svals, tvals = meta_functions.generate_discretization(
                                    tQA, H_args, N_args[1])

	# Check if JSON exists.
    prefix = 'tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = '+ str(args)
    simulation_filename = meta.SAVE_LOCATION + prefix + '.json'
    
#     print("Testing to see if JSON exists...")
    if not Path(simulation_filename).is_file():
		print ("The following file does not exist. To initialize the file, run generate.py:")
		print(simulation_filename)
    else:
#         print ("Downloading the simulation data in the following JSON...")
#         print(simulation_filename)
#         print("loading JSON...")
        simulation = json.loads(open(simulation_filename).read())
        print("Finished loading JSON. The simulation has {} time steps...".format(len(svals)
                ))
        
        # Preprocess the dict for numerical and graphical analysis:
        simulation['svals'] = np.array(simulation['svals'])
        simulation['linblad_real_part'] = np.array(simulation['linblad_real_part'])
        simulation['linblad_imaginary_part'] = np.array(simulation['linblad_imaginary_part'])
        simulation['rho_real_part'] = np.array(simulation['rho_real_part'])
        simulation['rho_imaginary_part'] = np.array(simulation['rho_imaginary_part'])
        simulation['eq_dist'] = np.array(simulation['eq_dist'])
        end = time()
        print("Process complete; simulation loaded in {} seconds.".format(end-start))
        
        return simulation
    
def time_series(tensors, multi_index):
    if len(multi_index) == 4:
        i, j, k, l = multi_index
        return np.array([tensor[i, j, k, l] for tensor in tensors])
    elif len(multi_index) == 2:
        i, j = multi_index
        return np.array([tensor[i, j] for tensor in tensors])

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = map(float, [5*10**(-6), 0.2, 0.3, 1, 6, 6, 0.001, 2, 1000, 0])
sim_N6_1000 = simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])
# Out:
# Finished loading JSON. The simulation has 1897 time steps...
# Process complete; simulation loaded in 8.89183497429 seconds.

# %%
x = sim_N6_1000['svals']
y = time_series(sim_N6_1000['rho_real_part'], [0, 0]) + time_series(sim_N6_1000['rho_real_part'], [1, 1])
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()

# %%
x = sim_N6_1000['svals']
y = time_series(sim_N6_1000['eq_dist'], [0, 0]) + time_series(sim_N6_1000['eq_dist'], [1, 1])
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = map(float, [5*10**(-6), 0.2, 0.3, 1, 6, 6, 0.001, 2, 5000, 0])
sim_N6_5000 = simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])
# Out:
# Finished loading JSON. The simulation has 5896 time steps...
# Process complete; simulation loaded in 9.84970188141 seconds.

# %%
x = sim_N6_5000['svals']
y = time_series(sim_N6_5000['rho_real_part'], [0, 0]) + time_series(sim_N6_5000['rho_real_part'], [1, 1])
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = map(float, [5*10**(-6), 0.2, 0.3, 1, 6, 6, 0.001, 20, 15000, 0])
sim_N6_15000 = simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])
# Out:
# Finished loading JSON. The simulation has 15020 time steps...
# Process complete; simulation loaded in 25.2928538322 seconds.

# %%
x = sim_N6_15000['svals']
y = time_series(sim_N6_15000['rho_real_part'], [0, 0]) + time_series(sim_N6_15000['rho_real_part'], [1, 1])
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence = map(float, [5*10**(-9), 0.2, 0.3, 1, 6, 6, 0.001, 10, 10000, 0])
sim_N6 = simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])
# Out:
# Finished loading JSON. The simulation has 10476 time steps...
# Process complete; simulation loaded in 20.0525200367 seconds.

# %%
x = sim_N6['svals']
print(len(x))
y = time_series(sim_N6['rho_real_part'], [0, 0]) + time_series(sim_N6['rho_real_part'], [1, 1])
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()
# Out:
# 10476

# %%
plt.figure(figsize=(12,7))
plt.plot(x)
plt.show()
