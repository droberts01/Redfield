# %%
#---------------
# analysis.py 
# Provides functions for analysis of
# the Redfield quantum master equation and its solution.
# import jtplot submodule from jupyterthemes

# currently installed theme will be used to
# set plot style if no arguments provided

import json
import meta
import meta_functions
import numpy as np
from time import time
from pathlib import Path
import matplotlib.pyplot as plt

# call as "simulate([tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence])"
def simulate(args):
    start = time()
    
    # Parse input as float
    for j in range(len(args) - 1):
        args[j] = float(args[j])
    tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU = args
    tQA = float('{:0.3e}'.format(tQA))
    args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
                
    decoherence = int(decoherence)
	# args for constructing F-model Hamiltonian
    H_args = [I, J, K, int(N)]

	# args pertaining to numerical implementation of the QME
    N_args = [int(Nc), [step, window_size, int(num_samples)]]
    svals, bad_svals, tvals = meta_functions.generate_discretization(tQA, H_args, N_args[1])[:3]

	# Check if JSON exists.
    prefix = 'tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU = '+ str(args)
    simulation_filename = meta.SAVE_LOCATION + prefix + '.json'
    
#     print("Testing to see if JSON exists...")
    if not Path(simulation_filename).is_file():
		print ("The following file does not exist. To initialize the file, run generate.py:")
		print(simulation_filename)
    else:
#         print ("Downloading the simulation data in the following JSON...")
#         print(simulation_filename)
#         print("loading JSON...")
        simulation = json.loads(open(simulation_filename).read())
        print("Finished loading JSON. The simulation has {} time steps...".format(len(svals)
                ))
        
        # Preprocess the dict for numerical and graphical analysis:
        simulation['svals'] = np.array(simulation['svals'])
        simulation['linblad_real_part'] = np.array(simulation['linblad_real_part'])
        simulation['linblad_imaginary_part'] = np.array(simulation['linblad_imaginary_part'])
        simulation['rho_real_part'] = np.array(simulation['rho_real_part'])
        simulation['rho_imaginary_part'] = np.array(simulation['rho_imaginary_part'])
        simulation['eq_dist'] = np.array(simulation['eq_dist'])
        end = time()
        print("Process complete; simulation loaded in {} seconds.".format(end-start))
        
        return simulation
    
def plot_component(tensors, multi_index):
    if len(multi_index) == 4:
        i, j, k, l = multi_index
        return np.array([tensor[i, j, k, l] for tensor in tensors])
    elif len(multi_index) == 2:
        i, j = multi_index
        return np.array([tensor[i, j] for tensor in tensors])
    
def plot_trace(tensors):
    return np.array([sum(tensor[i, i] for i in range(len(tensor[0])) ) for tensor in tensors])

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 5, 6, 0.001, 10, 10000, 1, 0, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N5 = simulate(args)
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 7, 6, 0.001, 10, 10000, 1, 0, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N7 = simulate(args)
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 9, 6, 0.001, 10, 10000, 1, 0, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N9 = simulate(args)
# Out:
# Finished loading JSON. The simulation has 10137 time steps...
# Process complete; simulation loaded in 18.4185669422 seconds.
# Finished loading JSON. The simulation has 10908 time steps...
# Process complete; simulation loaded in 20.1514110565 seconds.
# Finished loading JSON. The simulation has 10992 time steps...
# Process complete; simulation loaded in 20.7227871418 seconds.

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 5, 6, 0.001, 10, 10000, 1, 0, 0, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N5_RAM = simulate(args)

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 5, 6, 0.001, 10, 10000, 1, 0, 1, "Lome"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N5_lowT = simulate(args)
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 7, 6, 0.001, 10, 10000, 1, 0, 1, "Lome"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N7_lowT = simulate(args)
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads,  CPU = [5*10**(-6), 0.2, 0.24, 1, 9, 6, 0.001, 10, 10000, 1, 0, 1, "Lome"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, store_linblads, CPU]
sim_N9_lowT = simulate(args)
# Out:
# Finished loading JSON. The simulation has 10137 time steps...
# Process complete; simulation loaded in 19.9759321213 seconds.
# Finished loading JSON. The simulation has 10908 time steps...
# Process complete; simulation loaded in 20.0472650528 seconds.
# Finished loading JSON. The simulation has 10992 time steps...
# Process complete; simulation loaded in 21.6427710056 seconds.

# %%
x = sim_N5_RAM['svals']
print(len(x))
y = plot_component(sim_N5_RAM['rho_real_part'], [0, 0]) + plot_component(sim_N5_RAM['rho_real_part'], [1, 1])
z = plot_component(sim_N5_RAM['eq_dist'], [0, 0]) + plot_component(sim_N5_RAM['eq_dist'], [1, 1])
z2 = plot_component(sim_N5_RAM['eq_dist'], [2, 2]) + plot_component(sim_N5_RAM['eq_dist'], [3, 3])

# %%
x = sim_N5['svals']
print(len(x))
y = plot_component(sim_N5['rho_real_part'], [0, 0]) + plot_component(sim_N5['rho_real_part'], [1, 1])
z = plot_component(sim_N5['eq_dist'], [0, 0]) + plot_component(sim_N5['eq_dist'], [1, 1])
z2 = plot_component(sim_N5['eq_dist'], [2, 2]) + plot_component(sim_N5['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()

x = sim_N7['svals']
print(len(x))
y = plot_component(sim_N7['rho_real_part'], [0, 0]) + plot_component(sim_N7['rho_real_part'], [1, 1])
z = plot_component(sim_N7['eq_dist'], [0, 0]) + plot_component(sim_N7['eq_dist'], [1, 1])
z2 = plot_component(sim_N7['eq_dist'], [2, 2]) + plot_component(sim_N7['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()


x = sim_N9['svals']
print(len(x))
y = plot_component(sim_N9['rho_real_part'], [0, 0]) + plot_component(sim_N9['rho_real_part'], [1, 1])
z = plot_component(sim_N9['eq_dist'], [0, 0]) + plot_component(sim_N9['eq_dist'], [1, 1])
z2 = plot_component(sim_N9['eq_dist'], [2, 2]) + plot_component(sim_N9['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()
# Out:
# 10137
# 10908
# 10992

# %%
x = sim_N5_lowT['svals']
print(len(x))
y = plot_component(sim_N5_lowT['rho_real_part'], [0, 0]) + plot_component(sim_N5_lowT['rho_real_part'], [1, 1])
z = plot_component(sim_N5_lowT['eq_dist'], [0, 0]) + plot_component(sim_N5_lowT['eq_dist'], [1, 1])
z2 = plot_component(sim_N5_lowT['eq_dist'], [2, 2]) + plot_component(sim_N5_lowT['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()

x = sim_N7_lowT['svals']
print(len(x))
y = plot_component(sim_N7_lowT['rho_real_part'], [0, 0]) + plot_component(sim_N7_lowT['rho_real_part'], [1, 1])
z = plot_component(sim_N7_lowT['eq_dist'], [0, 0]) + plot_component(sim_N7_lowT['eq_dist'], [1, 1])
z2 = plot_component(sim_N7_lowT['eq_dist'], [2, 2]) + plot_component(sim_N7_lowT['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()


x = sim_N9_lowT['svals']
print(len(x))
y = plot_component(sim_N9_lowT['rho_real_part'], [0, 0]) + plot_component(sim_N9_lowT['rho_real_part'], [1, 1])
z = plot_component(sim_N9_lowT['eq_dist'], [0, 0]) + plot_component(sim_N9_lowT['eq_dist'], [1, 1])
z2 = plot_component(sim_N9_lowT['eq_dist'], [2, 2]) + plot_component(sim_N9_lowT['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
# plt.plot(x[5000:8000], y[5000:8000], x[5000:8000], z[5000:8000])
plt.plot(x[:],y[:],x[:],z[:])
plt.show()
# Out:
# 10137
# 10908
# 10992

# %%
x = [5,7,9]
y = [.92,.34,.18]

plt.figure(figsize=(12,7))
plt.plot(x,y)
plt.show()

# %%
x = sim_N6['svals']
print(len(x))
y = time_series(sim_N6['rho_real_part'], [0, 0]) + time_series(sim_N6['rho_real_part'], [1, 1])
z = time_series(sim_N6['eq_dist'], [0, 0]) + time_series(sim_N6['eq_dist'], [1, 1])
z2 = time_series(sim_N6['eq_dist'], [2, 2]) + time_series(sim_N6['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
plt.plot(x, y, x, z, x, z2)
plt.show()
# Out:
# 10476

# %%
x = sim_N6['svals']
print(len(x))
y = time_series(sim_N6['linblad_real_part'], [1, 1, 1, 2])
# z = time_series(sim_N6['eq_dist'], [0, 0]) + time_series(sim_N6['eq_dist'], [1, 1])
# z2 = time_series(sim_N6['eq_dist'], [2, 2]) + time_series(sim_N6['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
plt.plot(x[3000:7000], y[3000:7000])#, x, z, x, z2)
plt.show()
# Out:
# 10476

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU = [5*10**(-6), 0.2, 0.24, 1, 6, 4, 0.001, 10, 10000, 1, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU]
for j in range(len(args)-1):
    args[j] = float(args[j])
sim_N7 = simulate(args)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-19723a09aad1> in <module>()
# ----> 1 tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU = [5*10**(-6), 0.2, 0.24, 1, 6, 4, 0.001, 10, 10000, 1, 1, "Home"]
#       2 args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU]
#       3 for j in range(len(args)-1):
#       4     args[j] = float(args[j])
#       5 sim_N7 = simulate(args)
#
# ValueError: too many values to unpack

# %%
x = sim_N7['svals']
print(len(x))
y = time_series(sim_N7['rho_real_part'], [0, 0]) + time_series(sim_N7['rho_real_part'], [1, 1])
z = time_series(sim_N7['eq_dist'], [0, 0]) + time_series(sim_N7['eq_dist'], [1, 1])
z2 = time_series(sim_N7['eq_dist'], [2, 2]) + time_series(sim_N7['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
plt.plot(x[4000:7000], y[4000:7000], x[4000:7000], z[4000:7000], x[4000:7000], z2[4000:7000])
plt.show()
# Out:
# 10792

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU = [5*10**(-6), 0.2, 0.24, 1, 6, 4, 0.001, 10, 10000, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU]
for j in range(len(args)-1):
    args[j] = float(args[j])
sim_N9 = simulate(args)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-83ca5112abb2> in <module>()
#       3 for j in range(len(args)-1):
#       4     args[j] = float(args[j])
# ----> 5 sim_N9 = simulate(args)
#
# <ipython-input-8-246069e71808> in simulate(args)
#      25     for j in range(len(args) - 1):
#      26         args[j] = float(args[j])
# ---> 27     tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, CPU = args
#      28     tQA = float('{:0.3e}'.format(tQA))
#      29     args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, LF_noise, CPU]
#
# ValueError: need more than 11 values to unpack

# %%
x = sim_N9['svals']
print(len(x))
y = time_series(sim_N9['rho_real_part'], [0, 0]) + time_series(sim_N9['rho_real_part'], [1, 1])
z = time_series(sim_N9['eq_dist'], [0, 0]) + time_series(sim_N9['eq_dist'], [1, 1])
z2 = time_series(sim_N9['eq_dist'], [2, 2]) + time_series(sim_N9['eq_dist'], [3, 3])


plt.figure(figsize=(12,7))
plt.plot(x[4000:7000], y[4000:7000], x[4000:7000], z[4000:7000], x[4000:7000], z2[4000:7000])
plt.show()
# Out:
# 10958

# %%
x = sim_N9['svals']
y = time_series(sim_N9['rho_real_part'], [0, 0]) + time_series(sim_N9['rho_real_part'], [1, 1]) + time_series(sim_N9['rho_real_part'], [2, 2]) + time_series(sim_N9['rho_real_part'], [3, 3])
plt.figure(figsize=(12,7))
plt.plot(x, z)
plt.show()

# %%
tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU = [5*10**(-6), 0.2, 0.3, 1, 5, 4, 0.001, 10, 10000, 1, "Home"]
args = [tQA, I, J, K, N, Nc, step, window_size, num_samples, decoherence, CPU]
for j in range(len(args)-1):
    args[j] = float(args[j])
sim_N5 = simulate(args)
# Out:
# Finished loading JSON. The simulation has 10045 time steps...
# Process complete; simulation loaded in 4.45727205276 seconds.

# %%
x = sim_N5['svals']
y = plot_component(sim_N5['rho_real_part'],[0,0])+plot_component(sim_N5['rho_real_part'],[1,1]) 
plt.figure(figsize=(12,7))
plt.plot(x, y)
plt.show()

# %%
len(sim_N5['rho_real_part'][0])
# Out:
# 4

# %%
import meta_functions

# %%
f = meta_functions.S(0.2,1)
x = np.arange(-10**4, 10**4,10**2)
y = map(f, x)
plt.plot(x,y)
plt.show()
